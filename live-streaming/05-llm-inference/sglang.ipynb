# %%
from sglang.utils import (
    execute_shell_command,
    wait_for_server,
    terminate_process,
    print_highlight,
)

import os

# %%
os.environ["TRITON_PTXAS_PATH"]="/usr/local/cuda/bin/ptxas"

# %%
server_process = execute_shell_command(
    "python -m sglang.launch_server --model-path /kaggle/input/deepseek-r1/transformers/deepseek-r1-distill-qwen-14b/1 --port 30020 --host 0.0.0.0 --tp-size 4"
)

wait_for_server("http://localhost:30020")
# Out:
# <strong style='color: #00008B;'><br><br>                    NOTE: Typically, the server runs in a separate terminal.<br>                    In this notebook, we run the server and notebook code together, so their outputs are combined.<br>                    To improve clarity, the server logs are displayed in the original black color, while the notebook outputs are highlighted in blue.<br>                    </strong>

# %%
import openai

problem = "Solve the integral $sin(x)/x$ from 0 to infinity using Feynmans trick."

client = openai.Client(base_url="http://127.0.0.1:30020/v1", api_key="None")

response = client.chat.completions.create(
    model="/kaggle/input/deepseek-r1/transformers/deepseek-r1-distill-qwen-14b/1",
    messages=[
        {"role": "user", "content": problem},
    ],
    temperature=0,
    max_tokens=4096,
)

# %%
print_highlight(response.choices[0].message.content)
# Out:
# <strong style='color: #00008B;'><think><br>Okay, so I need to solve the integral of sin(x)/x from 0 to infinity using Feynman's trick. Hmm, I remember that Feynman's trick involves introducing a parameter into the integral and then differentiating with respect to that parameter to simplify the problem. Let me try to recall how that works.<br><br>First, the integral I need to evaluate is:<br><br>\[<br>\int_{0}^{\infty} \frac{\sin(x)}{x} dx<br>\]<br><br>I think this integral is known as the Dirichlet integral, and its value is π/2. But I need to derive it using Feynman's method.<br><br>So, how do I introduce a parameter here? Maybe I can consider a function that depends on a parameter, say 'a', such that when 'a' takes a specific value, the integral becomes the one I need. Let me think about how to define such a function.<br><br>One common approach is to introduce a parameter into the integrand. For example, I can define:<br><br>\[<br>I(a) = \int_{0}^{\infty} \frac{\sin(ax)}{x} dx<br>\]<br><br>Then, when a = 1, I get the integral I need. So, my goal is to find I(1).<br><br>Now, to use Feynman's trick, I should differentiate I(a) with respect to 'a' and see if that simplifies the integral.<br><br>Let's compute dI/da:<br><br>\[<br>\frac{dI}{da} = \frac{d}{da} \int_{0}^{\infty} \frac{\sin(ax)}{x} dx = \int_{0}^{\infty} \frac{\partial}{\partial a} \left( \frac{\sin(ax)}{x} \right) dx<br>\]<br><br>Since differentiation under the integral sign is valid here (I think by Leibniz's rule), this should be okay. So, computing the partial derivative:<br><br>\[<br>\frac{\partial}{\partial a} \left( \frac{\sin(ax)}{x} \right) = \frac{\cos(ax) \cdot x}{x} = \cos(ax)<br>\]<br><br>So, we have:<br><br>\[<br>\frac{dI}{da} = \int_{0}^{\infty} \cos(ax) dx<br>\]<br><br>Wait, but the integral of cos(ax) from 0 to infinity is not convergent in the traditional sense because cos(ax) oscillates and doesn't decay. Hmm, that's a problem. Maybe I need to consider a different approach or perhaps a different parameterization.<br><br>Alternatively, maybe I should introduce a convergence factor, like e^{-ax}, to make the integral convergent, and then take the limit as the parameter goes to zero. Let me try that.<br><br>Let me redefine I(a) as:<br><br>\[<br>I(a) = \int_{0}^{\infty} \frac{\sin(x)}{x} e^{-ax} dx<br>\]<br><br>Here, 'a' is a positive parameter that ensures convergence. Then, when a approaches 0, I should recover the original integral.<br><br>So, now, let's compute dI/da:<br><br>\[<br>\frac{dI}{da} = \frac{d}{da} \int_{0}^{\infty} \frac{\sin(x)}{x} e^{-ax} dx = \int_{0}^{\infty} \frac{\partial}{\partial a} \left( \frac{\sin(x)}{x} e^{-ax} \right) dx<br>\]<br><br>Again, by Leibniz's rule, this is valid because the convergence is maintained. So, computing the partial derivative:<br><br>\[<br>\frac{\partial}{\partial a} \left( \frac{\sin(x)}{x} e^{-ax} \right) = \frac{\sin(x)}{x} \cdot (-x) e^{-ax} = -\sin(x) e^{-ax}<br>\]<br><br>Therefore,<br><br>\[<br>\frac{dI}{da} = -\int_{0}^{\infty} \sin(x) e^{-ax} dx<br>\]<br><br>Okay, so now I have an integral involving sin(x) multiplied by an exponential. I think I can compute this integral using integration by parts or perhaps by recalling standard integrals.<br><br>I remember that the integral of e^{-ax} sin(x) dx from 0 to infinity is a standard result. Let me recall the formula:<br><br>\[<br>\int_{0}^{\infty} e^{-ax} \sin(bx) dx = \frac{b}{a^2 + b^2}<br>\]<br><br>In our case, b = 1, so:<br><br>\[<br>\int_{0}^{\infty} e^{-ax} \sin(x) dx = \frac{1}{a^2 + 1}<br>\]<br><br>Therefore, substituting back into dI/da:<br><br>\[<br>\frac{dI}{da} = -\frac{1}{a^2 + 1}<br>\]<br><br>So, now we have a differential equation for I(a):<br><br>\[<br>\frac{dI}{da} = -\frac{1}{a^2 + 1}<br>\]<br><br>To find I(a), we can integrate both sides with respect to 'a':<br><br>\[<br>I(a) = -\int \frac{1}{a^2 + 1} da + C<br>\]<br><br>The integral of 1/(a^2 + 1) da is arctan(a) + C. So,<br><br>\[<br>I(a) = -\arctan(a) + C<br>\]<br><br>Now, we  ...

# %%
terminate_process(server_process)
